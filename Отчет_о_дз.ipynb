# %% [markdown]
# Я решил создать бд на основе данных о людях 18 лет с двумя колонками: ростом и весом. Там 25000 записей

# %% [markdown]
# После поднятия сервера с mongodb скопируем туда файл с данными:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# На сервере заполним таблицу данными из файла

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Посмотрим на достаточно низких людей и отсортируем их по весу в порядке убывания

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Изменим рост самого высокого человека: был 75 дюймов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Добавим ему 5 дюймов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Добавим низенького тяжелого человека

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Посмотрим время выполнения поиска людей ростом выше 70 дюймов. Получили 10 милисекунд

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Добавим индекс с колонку роста и тот же запрос будет выдавать результат уже за 6 миллисекунд, т.е. подняли производительность.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
